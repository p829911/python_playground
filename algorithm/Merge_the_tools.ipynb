# %%
string = "AABCAAADA"
k = 3

# %%
string = "..."

# %%
len(string)
# Out:
# 6904

# %%
k = 3452

# %%
s_num = int(len(string) / k)

# %%
for i in range(s_num):
    s = string[i*k:(i+1)*k]
    u = []
    for t in s:
        if t not in u:
            u.append(t)
    print("".join(u))
# Out:
# AB
# CA
# AD
