# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()

# %%
import mglearn

# %%
iris_dataset.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris_dataset.data, iris_dataset.target, random_state=0)

# %%
iris_dataframe = pd.DataFrame(X_train, columns=iris_dataset.feature_names)

# %%
iris_dataframe.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.9               3.0                4.2               1.5
# 1                5.8               2.6                4.0               1.2
# 2                6.8               3.0                5.5               2.1
# 3                4.7               3.2                1.3               0.2
# 4                6.9               3.1                5.1               2.3

# %%
pd.plotting.scatter_matrix(iris_dataframe, c=y_train, figsize=(15, 15), marker='o',
                           hist_kwds={'bins': 20}, s=60, alpha=.8, cmap=mglearn.cm3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12cbc0080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d6f4f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d7278d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d755278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d77bbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d7a8588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d7ceef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d7f98d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d7f9908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d84fba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d87c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d8a3eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d8ce860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d8fc208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d922b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d94f518>]],
#       dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
X_new = np.array([[5, 2.9, 1, 0.2]])

# %%
knn.predict(X_new)
# Out:
# array([0])

# %%
iris_dataset.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
y_pred = knn.predict(X_test)

# %%
np.mean(y_test == y_pred)
# Out:
# 0.9736842105263158

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9736842105263158

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.94      0.97        16
#            2       0.90      1.00      0.95         9
#
#    micro avg       0.97      0.97      0.97        38
#    macro avg       0.97      0.98      0.97        38
# weighted avg       0.98      0.97      0.97        38
